# %% [markdown]
# <h1 style="font-size: 48px; font-weight: bold;">FizzBuzz Problem</h1>
# <img src="https://www.askpython.com/wp-content/uploads/2021/09/feautured_img_FizzBuzz.png" alt="image" width="700"/>

# %% [markdown]
# ## HashMap
# How would ypu approach such a problem? <br>
# <img src="https://miro.medium.com/v2/resize:fit:640/format:webp/1*TBwDJrKkzynAe7oiTSuXCg.png" alt="image" width="700"/>

# %%
#Three conditions with conditional statement with if 
#loop that iterates 

for i in range(1, 101):
    if i % 3 == 0 and i % 5 == 0: #modulo operator % & each value of i in the loop is treated as an integer
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# **It works!!!** <br>
# ![Cool](https://media1.tenor.com/m/psvzo0hhSO0AAAAC/cool.gif)

# %% [markdown]
# ## Add an additional condition
# BUT what if we were to add more conditions? Still while itereting over the 100 answers. <br>
# <span style="color:green; font-weight:bold;">Now please add Bazz if divisible by 7!</span> <br>
# <img src="https://miro.medium.com/v2/resize:fit:640/format:webp/0*jo6iQh-FlG3BZaCj.jpeg" alt="image" width="400"/> <br>
# What now? <br>
# ![Cat Explosion](https://media1.tenor.com/m/BwDMS0SVbdYAAAAd/cat-explosion.gif) <br>
# <iframe width="560" height="315" src="https://www.youtube.com/embed/9LLgXPF2rZ0" frameborder="0" allowfullscreen></iframe>

# %%
# Use dictionary. It’s flexible if you want to add more conditions 

fizzbuzz_dict = {3: "Fizz", 5: "Buzz", 7: "Bazz"}

for i in range(1, 101):
    output = ""
    for key, value in fizzbuzz_dict.items():
        if i % key == 0:
            output += value
    print(output or i)

# keys are divisors (3, 5 and 7) and values are the corresponding words ("Fizz", "Buzz", "Bazz").
#We check each divisor and add the corresponding word to output if i is divisible by that key.
#If output is empty (i.e., not divisible by 3 or 5), we print i; otherwise, we print output.
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# Bazz
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# Bazz
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# FizzBazz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# Bazz
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# BuzzBazz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# FizzBazz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# Bazz
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# Bazz
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# FizzBazz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# BuzzBazz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# Bazz
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# FizzBazz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# Bazz
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# Bazz
# Fizz
# Buzz

# %% [markdown]
# <div style="text-align: center;">
#     <span style="color:green; font-weight:bold; font-size:30px;">You made it!</span><br><br>
#     <img src="https://preview.redd.it/what-kanye-song-always-makes-you-cry-happy-tears-v0-29rwqwl9n83b1.jpg?width=1080&crop=smart&auto=webp&s=42c799c29a25d91437d247bef4ab1d26abfb022a" alt="Kanye" width="500"/>
# </div>
